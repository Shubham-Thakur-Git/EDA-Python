# %% [markdown]
# **Install Packages**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r"C:\Users\thaku\Documents\MacBook\Shubham's Stuff\Naresh IT\Data_Science_AI_Omkar Sir\DataFiles\Visadataset.csv")

cat_columns=visa_df.select_dtypes(include='object').columns
num_columns=visa_df.select_dtypes(exclude='object').columns

# %% [markdown]
# **Encoding**
#
# - Encoding means convert categorical columns data to Numerical data
#
# - Because ML models Expect the data should be in Numerical format
#
# - ML models developed by Math algorithms
#
# - It is very very important to apply encoding
#
# - The following methods are
#
#     - map
#
#     - np.where
#
#     - one hot encoding
#
#     - Lable Encoder

# %% [markdown]
# **Map**
#
# - map is one method to convert categorical values to numerical
#
# - Take one categorical column
#
# - Get the unique lables first
#
# - make a dictionary with assign a number to each lable
#
# - for example case_status has two lables
#
#     - Certified
#
#     - Denied
#
# - Assign 0 to Certified, 1 to Denied
#
# - Create a dictionary lables as keys, number as values only
#
# - {'Certified':0,'Denied':1}

# %%
# step-1: read the column
# step-2: get the unique lables
# step-3: make a dictionary
# step-4: apply the map

# %%
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
d={'Certified':0,'Denied':1}
visa_df['case_status_new']=visa_df['case_status'].map(d)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# I want to apply the map method for all categorical columns
# Step-1: we need to get unique lables
# Step-2: we need to get a numbers = len unique lables
# Step-3: we need to create a dictionary

# %%
unique_lables=sorted(visa_df['case_status'].unique())
list1=[i for i in range(len(unique_lables))]
dict1=dict(zip(unique_lables,list1))
dict1
visa_df['case_status1']=visa_df['case_status'].map(dict1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **Dictionary Comprehension**

# %%
{key:value for key,value in zip(unique_lables,list1)}
# Out:
# {'Certified': 0, 'Denied': 1}

# %%
{j:i for i, j in enumerate(unique_lables)}
# Out:
# {'Certified': 0, 'Denied': 1}

# %%
for i in cat_columns[1:]:
    unique_lables=sorted(visa_df[i].unique())
    dict1 = {key:value for value, key in enumerate(unique_lables)}
    visa_df[i]=visa_df[i].map(dict1)
visa_df
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          1                      2                   0
# 1         EZYV02          1                      3                   1
# 2         EZYV03          1                      0                   0
# 3         EZYV04          1                      0                   0
# 4         EZYV05          0                      3                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          1                      0                   1
# 25476  EZYV25477          1                      2                   1
# 25477  EZYV25478          1                      3                   1
# 25478  EZYV25479          1                      3                   1
# 25479  EZYV25480          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %% [markdown]
# **LableEncoder**
#
# - LableEncoder is a method to convert categorical data to Numerical data
#
# - LableEncoder is a same way , how we did in the map
#
# - The for loop map method we explored
#
# - But The LableEncoder also do the same
#
# - It is under **sickit-learn** we usually called as **sklearn**
#
# - Under skleran we have class called as preprocessing
#
# - Because currently we are doing data preprocessing only
#
# - under preprocessing class we have a method calles as **LableEncoder**
#
# - sklearn
#     - preprocessing
#         - LableEncoder
#
# - Any sklearn pacckage has 3 steps
#
#     - Step-1: Read the package
#
#     - Step-2: Save the package
#
#     - Step-3: Apply fit transform on data

# %%
# Read the data
visa_df=pd.read_csv(r"C:\Users\thaku\Documents\MacBook\Shubham's Stuff\Naresh IT\Data_Science_AI_Omkar Sir\DataFiles\Visadataset.csv")

# %%
# Step-1: Read the package / load the method
from sklearn.preprocessing import LabelEncoder
# Step-2: save the package / call the method
le=LabelEncoder()
# Step-3: Apply fit transform on data
visa_df['case_status']=le.fit_transform(visa_df['case_status'])
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# Read the data
from sklearn.preprocessing import LabelEncoder
visa_df=pd.read_csv(r"C:\Users\thaku\Documents\MacBook\Shubham's Stuff\Naresh IT\Data_Science_AI_Omkar Sir\DataFiles\Visadataset.csv")
cat_columns=visa_df.select_dtypes(include='object').columns
le=LabelEncoder()
for i in cat_columns:
    visa_df[i]=le.fit_transform(visa_df[i])
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %% [markdown]
# **fit and transform**
#
# - fit means develop the logic
#
# - transform means process the logic
#
# - if we observe in map method first we developed dictionary logic
#
# - the we appply that dictionary to column
#
# - Developing the dictionary is kind of fit
#
# - apply the dictionary to column means we are transforming the data cat to num
#
# - whenever we are transforming or changing the data then use **fit transform**
#
# - if we are not changing the data then only **fit**

# %% [markdown]
# **np.where**

# %% [markdown]
# - using np.where also we can change the Categorical data to Numerical
#
# - But np.where is only for binary condition
#
# - np.where is same as if-else
#
# - if condition is True : will apply True value
#
# - if condition is False: will apply False value
#
# - so np.where use for only binary lables
#
# - A column should have only two unique lables

# %%
# value =='certified'  replace with 0
# otherwise 1
visa_df=pd.read_csv(r"C:\Users\thaku\Documents\MacBook\Shubham's Stuff\Naresh IT\Data_Science_AI_Omkar Sir\DataFiles\Visadataset.csv")
con=visa_df['case_status']=='Certified'
visa_df['case_status']=np.where(con,0,1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **One hot encoder**
#
# - One hot means if one will be ON , another will be OFF
#
# - ON represents with 1
#
# - Off represents with 0
#
# - For example case status has two unqiue lables
#
#     - Certified
#
#     - Denied
#
# - One hot encoder creates new columns which is equal to number of uniuqe lables
#
# - For example case status will create two new extra columns
#
#     - case_status_Certified
#
#     - case_status_Denied
#
# |case_status|case_status_certified|case_status_denied|
# |-|-|-|
# |Denied|0|1|
# |Certified|1|0|
# |Denied|0|1|

# %%
visa_df=pd.read_csv(r"C:\Users\thaku\Documents\MacBook\Shubham's Stuff\Naresh IT\Data_Science_AI_Omkar Sir\DataFiles\Visadataset.csv")

# %% [markdown]
# **pd.get_dummies**

# %%
df=pd.get_dummies(visa_df['case_status'],dtype='int')
df['case_status']=visa_df['case_status'].values
df['dummy']=[i for i in range(len(visa_df))]
df
# Out:
#        Certified  Denied case_status  dummy
# 0              0       1      Denied      0
# 1              1       0   Certified      1
# 2              0       1      Denied      2
# 3              0       1      Denied      3
# 4              1       0   Certified      4
# ...          ...     ...         ...    ...
# 25475          1       0   Certified  25475
# 25476          1       0   Certified  25476
# 25477          1       0   Certified  25477
# 25478          1       0   Certified  25478
# 25479          1       0   Certified  25479
#
# [25480 rows x 4 columns]

# %%
df1=pd.get_dummies(visa_df['case_status'],dtype='int')
df1
# Out:
#        Certified  Denied
# 0              0       1
# 1              1       0
# 2              0       1
# 3              0       1
# 4              1       0
# ...          ...     ...
# 25475          1       0
# 25476          1       0
# 25477          1       0
# 25478          1       0
# 25479          1       0
#
# [25480 rows x 2 columns]

# %%
df2=visa_df[['case_status']]
df2
# Out:
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 1 columns]

# %% [markdown]
# **Adding the two dataframes**
#
# - Merge
#
# - join
#
# - concat
#
# - append

# %%
# Concat:

pd.concat([visa_df[['case_status']],df1],axis=1)
# Out:
#       case_status  Certified  Denied
# 0          Denied          0       1
# 1       Certified          1       0
# 2          Denied          0       1
# 3          Denied          0       1
# 4       Certified          1       0
# ...           ...        ...     ...
# 25475   Certified          1       0
# 25476   Certified          1       0
# 25477   Certified          1       0
# 25478   Certified          1       0
# 25479   Certified          1       0
#
# [25480 rows x 3 columns]

# %%
# Merge:

pd.merge(visa_df[['case_status']],df1,left_index=True,right_index=True)
# Out:
#       case_status  Certified  Denied
# 0          Denied          0       1
# 1       Certified          1       0
# 2          Denied          0       1
# 3          Denied          0       1
# 4       Certified          1       0
# ...           ...        ...     ...
# 25475   Certified          1       0
# 25476   Certified          1       0
# 25477   Certified          1       0
# 25478   Certified          1       0
# 25479   Certified          1       0
#
# [25480 rows x 3 columns]

# %%
# Join:

visa_df[['case_status']].join(df1)
# Out:
#       case_status  Certified  Denied
# 0          Denied          0       1
# 1       Certified          1       0
# 2          Denied          0       1
# 3          Denied          0       1
# 4       Certified          1       0
# ...           ...        ...     ...
# 25475   Certified          1       0
# 25476   Certified          1       0
# 25477   Certified          1       0
# 25478   Certified          1       0
# 25479   Certified          1       0
#
# [25480 rows x 3 columns]

# %%
pd.get_dummies(visa_df,dtype='int')
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage  case_id_EZYV01  \
# 0                14513         2007         592.2029               1
# 1                 2412         2002       83425.6500               0
# 2                44444         2008      122996.8600               0
# 3                   98         1897       83434.0300               0
# 4                 1082         2005      149907.3900               0
# ...                ...          ...              ...             ...
# 25475             2601         2008       77092.5700               0
# 25476             3274         2006      279174.7900               0
# 25477             1121         1910      146298.8500               0
# 25478             1918         1887       86154.7700               0
# 25479             3195         1960       70876.9100               0
#
#        case_id_EZYV02  case_id_EZYV03  case_id_EZYV04  case_id_EZYV05  \
# ...

# %% [markdown]
# - In onehot encoder, new columns will be created
#
# - the new columns equal to number of unique lables
#
# - because of case status two extra columns created
#
# - because of continent 6 extra column are created
#
# - because of case id 25480 unique ids, 25480 columns created

# %%
count=0
for i in cat_columns:
    count=count+visa_df[i].nunique()

print(count+len(num_columns))
# Out:
# 25510

# %%
count=0
for i in cat_columns[1:]:            # Excluding the Case_id column
    count=count+visa_df[i].nunique()
print(count)
print(count+len(num_columns))
# Out:
# 27
# 30

# %% [markdown]
# **Advantages**
#
# - using one hot encoder we will get new columns
#
# - the new column values at a time only one will be **True**, another will be **False**
#
# - Which means new columns are **independet each other**
#
# - Independent means **no relation**
#
# - Means no **Multi collineraity**
#
# - Multicollineraity is an important propert in Machine learning
#
# - **Machine learning models expect the input columns should be independent eachother**
#
# - So one hot encoder gives the no multicollineraity

# %% [markdown]
# **Disadvantages**
#
# - the Disadvantage is It will increase many columns
#
# - in the above example the total columns becomes 25510
#
# - this is happend because of case id
#
# - in real time we will drop the id columns
#
# - eventhough if we drop still we are getting 30 columns
#
# - More columns means , more time to process
#
# - we required more infrstaructure (CPU-GPU-TPU)
#
# - This is called as **curse of dimensionality**
